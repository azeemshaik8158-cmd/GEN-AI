# %%
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain.tools import tool
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
import os
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY")
os.environ['LANGSMITH_TRACING']= 'true'
LANGSMITH_API_KEY = os.getenv("LANGSMITH_API_KEY")

# %%
llm = ChatOpenAI(model="gpt-4o-mini",temperature=0.2)

# %%
tavily = TavilySearchResults(max_results=3)

# %%
# websearch tool
@tool
def search(query: str) -> str:
    """
    Perform a real-time web search using Tavily
    to retrieve the latest AI industry news.
    """
    return str(tavily.invoke(query))


# Analysis tool
@tool
def analyze(text: str) -> str:
    """
    Analyze retrieved information to identify
    trends, risks, and opportunities.
    """
    return f"""
    You are an AI industry analyst.

    From the following data, extract:
    - Key trends
    - Potential risks
    - Emerging opportunities

    Data:
    {text}
    """


# Recommendations tool
@tool
def recommend(analysis: str) -> str:
    """
    Generate actionable business recommendations
    based on the analysis.
    """
    return f"""
    You are advising a startup founder.

    Based on the analysis, provide:
    - Business impact
    - Clear, actionable recommendations

    Analysis:
    {analysis}
    """


# Tools list
tools = [search, analyze, recommend]

# Creating the agent
agent = create_agent(tools=tools,model=llm)

# call agent
response = agent.invoke({
    "messages": [
        ("user", "Analyze current AI industry news and recommend actions for a startup")
    ]
})

response
# Out:
# {'messages': [HumanMessage(content='Analyze current AI industry news and recommend actions for a startup', additional_kwargs={}, response_metadata={}, id='47fcd17c-2e20-4475-ad2b-561f7b08d802'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 117, 'total_tokens': 132, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8bbc38b4db', 'id': 'chatcmpl-CqKnJgmOn23cIl1hys3edi0nZ7JrJ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b50e9-4c05-7531-8250-37690d0cc7f4-0', tool_calls=[{'name': 'search', 'args': {'query': 'AI industry news'}, 'id': 'call_qtQKeVSWwGrHnAUSXcdWjirn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 117, 'output_tokens': 15, 'total_tokens': 132, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='[{\'title\': \'The Latest AI News and AI Breakthroughs that Matter Most: 2025\', \'url\': \'https://www.crescendo.ai/news/latest-ai-news-and-updates\', \'content\': \'Date: December 14, 2025 Summary: OpenAI has announced the "OpenAI Academy for News Organizations," a new initiative designed to provide journalists and media outlets with the tools and training necessary to integrate AI into their workflows. The program offers financial grants, technical support, and access to OpenAI\\\'s latest models to help newsrooms automate administrative tasks and enhance investigative research. This move comes as part of a broader effort to build collaborative relationships [...] Date: December 18, 2025 Summary: Despite its reputation as a global tech hub, Israel’s AI startup ecosystem is facing significant headwinds due to a combination of geopolitical instability and shifting investment trends. Recent data shows a slowdown in seed-stage funding for new AI ventures as investors become more risk-averse. Industry leaders are calling for increased government support and clearer regulatory frameworks to ensure that the country remains competitive in the global race for AI [...] ### Channel 4 Debuts First-Ever AI News Presenter in UK TV History\', \'score\': 0.9943581}, {\'title\': \'AI Magazine: Home of AI and Artificial Intelligence News\', \'url\': \'https://aimagazine.com/\', \'content\': "AI Magazine connects the leading AI executives of the world\'s largest brands. Our platform serves as a digital hub for connecting industry leaders, covering a wide range of services including media and advertising, events, research reports, demand generation, information, and data services. With our comprehensive approach, we strive to provide timely and valuable insights into best practices, fostering innovation and collaboration within the AI community. Join us today to shape the future for [...] News & Articles ArticlesNewsInterviewsTop 10VideosIndustry Events   \\n       Magazines AI MagazineTechnology MagazineCyber Magazine   \\n       Reports & Whitepapers Company Reports   \\n       Topics Artificial IntelligenceApplicationsAR & VRData & AnalyticsInfrastructureMachine LearningTechnology   \\n       Webinars\\n       AI LIVE\\n       Advertise\\n       Editorial\\n    \\n\\nLogin\\n\\nRegister\\n\\n       Socials LinkedInTwitterFacebookInstagramYouTubeMedium   \\n       Login Register    \\n\\nImage 3", \'score\': 0.9875683}, {\'title\': \'AI News | Latest News | Insights Powering AI-Driven Business ...\', \'url\': \'https://www.artificialintelligence-news.com/\', \'content\': \'News\\n Categories\\n  + AI and Us\\n    - Environment & Sustainability\\n    - Human-AI Relationships\\n    - Open-Source & Democratised AI\\n    - Trust, Bias & Fairness\\n    - World of Work\\n  + AI in Action\\n    - Creative Industries\\n    - Cybersecurity AI\\n    - Education AI\\n    - Entertainment & Media\\n    - Finance AI\\n    - Government & Public Sector AI\\n    - Healthcare & Wellness AI\\n    - Legal Industry AI\\n    - Manufacturing & Engineering AI\\n    - Marketing AI\\n    - Utilities\\n    - Workforce & HR AI [...] Skip to content\\n\\nAI News is part of the TechForge Publications series\\n\\nSubscribe [...] AI in Action, AI Market Trends, Artificial Intelligence\\n\\n### Google’s Veo 3 AI video creation tools are now widely available\\n\\n36520 view(s)\\n\\nDeep Dives, Features, How It Works\\n\\n### Samsung’s tiny AI model beats giant reasoning LLMs\\n\\n28396 view(s)\\n\\nAI Market Trends, Creative Industries, Entertainment & Media, How It Works, Inside AI\\n\\n### E3 2018: Xbox FastStart uses machine learning to get into content faster\\n\\n23906 view(s)\\n\\nSee all\\n\\n## Latest\\n\\nView All Latest\\n\\nEnvironment & Sustainability\', \'score\': 0.9606575}]', name='search', id='370481b2-7f36-4ec1-8c43-6f2a4856f3ca', tool_call_id='call_qtQKeVSWwGrHnAUSXcdWjirn'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 170, 'prompt_tokens': 945, 'total_tokens': 1115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8bbc38b4db', 'id': 'chatcmpl-CqKnM3tpEJ0e8jkQpgVWw4ggBkcZb', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b50e9-56f3-7bd3-9e77-c52bcb57fba2-0', tool_calls=[{'name': 'analyze', 'args': {'text': "OpenAI has announced the 'OpenAI Academy for News Organizations,' a new initiative designed to provide journalists and media outlets with the tools and training necessary to integrate AI into their workflows. The program offers financial grants, technical support, and access to OpenAI's latest models to help newsrooms automate administrative tasks and enhance investigative research. This move comes as part of a broader effort to build collaborative relationships. Despite its reputation as a global tech hub, Israel’s AI startup ecosystem is facing significant headwinds due to a combination of geopolitical instability and shifting investment trends. Recent data shows a slowdown in seed-stage funding for new AI ventures as investors become more risk-averse. Industry leaders are calling for increased government support and clearer regulatory frameworks to ensure that the country remains competitive in the global race for AI."}, 'id': 'call_2VWV5b2j1XWux5dFnRxDXaNz', 'type': 'tool_call'}], usage_metadata={'input_tokens': 945, 'output_tokens': 170, 'total_tokens': 1115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="\n    You are an AI industry analyst.\n\n    From the following data, extract:\n    - Key trends\n    - Potential risks\n    - Emerging opportunities\n\n    Data:\n    OpenAI has announced the 'OpenAI Academy for News Organizations,' a new initiative designed to provide journalists and media outlets with the tools and training necessary to integrate AI into their workflows. The program offers financial grants, technical support, and access to OpenAI's latest models to help newsrooms automate administrative tasks and enhance investigative research. This move comes as part of a broader effort to build collaborative relationships. Despite its reputation as a global tech hub, Israel’s AI startup ecosystem is facing significant headwinds due to a combination of geopolitical instability and shifting investment trends. Recent data shows a slowdown in seed-stage funding for new AI ventures as investors become more risk-averse. Industry leaders are calling for increased government support and clearer regulatory frameworks to ensure that the country remains competitive in the global race for AI.\n    ", name='analyze', id='0655f0ff-0c2b-4237-b737-12ce378da1e7', tool_call_id='call_2VWV5b2j1XWux5dFnRxDXaNz'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 190, 'prompt_tokens': 1317, 'total_tokens': 1507, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CqKnRH3cWxROB83RJTSUkx90WEbAH', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b50e9-6a5a-7e93-843f-f62e9fb35bcc-0', tool_calls=[{'name': 'recommend', 'args': {'analysis': "Key Trends: 1. Increased collaboration between AI companies and traditional industries, particularly in media and journalism. 2. Growing demand for AI tools that enhance operational efficiency and investigative capabilities. 3. A shift towards government involvement in supporting AI startups and establishing regulatory frameworks. \n\nPotential Risks: 1. Geopolitical instability affecting investment in AI startups, particularly in regions like Israel. 2. A slowdown in seed-stage funding leading to fewer new AI ventures. 3. Increased risk aversion among investors, which may hinder innovation and growth in the sector. \n\nEmerging Opportunities: 1. Development of AI solutions tailored for media and journalism, leveraging OpenAI's initiatives. 2. Potential for startups to advocate for and shape new regulatory frameworks that support innovation. 3. Opportunities for partnerships with government entities to secure funding and support for AI projects."}, 'id': 'call_vYWptql2ASkGU5pwcDJxbcAg', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1317, 'output_tokens': 190, 'total_tokens': 1507, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="\n    You are advising a startup founder.\n\n    Based on the analysis, provide:\n    - Business impact\n    - Clear, actionable recommendations\n\n    Analysis:\n    Key Trends: 1. Increased collaboration between AI companies and traditional industries, particularly in media and journalism. 2. Growing demand for AI tools that enhance operational efficiency and investigative capabilities. 3. A shift towards government involvement in supporting AI startups and establishing regulatory frameworks. \n\nPotential Risks: 1. Geopolitical instability affecting investment in AI startups, particularly in regions like Israel. 2. A slowdown in seed-stage funding leading to fewer new AI ventures. 3. Increased risk aversion among investors, which may hinder innovation and growth in the sector. \n\nEmerging Opportunities: 1. Development of AI solutions tailored for media and journalism, leveraging OpenAI's initiatives. 2. Potential for startups to advocate for and shape new regulatory frameworks that support innovation. 3. Opportunities for partnerships with government entities to secure funding and support for AI projects.\n    ", name='recommend', id='3745c394-25b2-46b0-8f2c-d7af48cde195', tool_call_id='call_vYWptql2ASkGU5pwcDJxbcAg'),
#   AIMessage(content='### Business Impact\nThe current landscape of the AI industry presents both challenges and opportunities for startups. The collaboration between AI companies and traditional sectors, especially media, indicates a growing market for AI solutions that enhance operational efficiency. However, geopolitical instability and a slowdown in funding pose risks that could affect growth and innovation. Startups that can navigate these challenges while leveraging emerging opportunities will be well-positioned for success.\n\n### Actionable Recommendations\n\n1. **Focus on Media and Journalism Solutions**:\n   - Develop AI tools specifically designed for media organizations to automate tasks and enhance investigative research. Consider partnerships with newsrooms to pilot these solutions and gather feedback.\n\n2. **Engage with Government Initiatives**:\n   - Actively seek partnerships with government bodies to align your startup with emerging regulatory frameworks. This could provide access to funding opportunities and support for your projects.\n\n3. **Diversify Funding Sources**:\n   - Given the slowdown in seed-stage funding, explore alternative funding avenues such as grants, crowdfunding, or strategic partnerships with established companies in the AI space.\n\n4. **Advocate for Supportive Policies**:\n   - Join industry groups or coalitions that advocate for clearer regulatory frameworks and increased government support for AI startups. This can help shape policies that benefit your business and the broader AI ecosystem.\n\n5. **Monitor Geopolitical Developments**:\n   - Stay informed about geopolitical trends that may impact investment in your region. Consider strategies to mitigate risks, such as diversifying your target markets or building a remote team.\n\nBy implementing these recommendations, your startup can capitalize on the current trends while mitigating potential risks, positioning itself for sustainable growth in the evolving AI landscape.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 332, 'prompt_tokens': 1721, 'total_tokens': 2053, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1280}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8bbc38b4db', 'id': 'chatcmpl-CqKnr9kvxQsLmQ6KqTxEwyUH9SXAr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b50e9-7f8f-7fb2-b06d-6ed244d4978d-0', usage_metadata={'input_tokens': 1721, 'output_tokens': 332, 'total_tokens': 2053, 'input_token_details': {'audio': 0, 'cache_read': 1280}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
response["messages"][-1].content
# Out:
# '### Business Impact\nThe current landscape of the AI industry presents both challenges and opportunities for startups. The trend towards collaboration with traditional sectors, such as journalism, indicates a growing market for AI tools that enhance efficiency and automate tasks. However, geopolitical instability and a slowdown in funding pose significant risks that could hinder growth and innovation.\n\n### Actionable Recommendations\n\n1. **Focus on Industry-Specific Solutions**:\n   - Develop AI tools specifically designed for sectors like journalism, where there is a clear demand for automation and efficiency. This could include tools for content generation, data analysis, or administrative task automation.\n\n2. **Collaborate with Established Organizations**:\n   - Seek partnerships with established media organizations or other traditional sectors to pilot your AI solutions. This will not only provide valuable feedback but also enhance credibility and visibility in the market.\n\n3. **Engage with Government Initiatives**:\n   - Actively participate in government programs aimed at supporting AI innovation. This could involve applying for grants, joining industry forums, or collaborating on research projects to align with regulatory frameworks and secure funding.\n\n4. **Diversify Funding Sources**:\n   - Given the slowdown in seed-stage funding, explore alternative funding sources such as venture capital, angel investors, or crowdfunding platforms. Building a strong business case and demonstrating traction can attract investment even in a challenging environment.\n\n5. **Monitor Geopolitical Developments**:\n   - Stay informed about geopolitical trends that may impact the AI landscape, especially if operating in regions like Israel. This awareness can help in strategic planning and risk management.\n\nBy leveraging these recommendations, your startup can navigate the current challenges while capitalizing on emerging opportunities in the AI industry.'
